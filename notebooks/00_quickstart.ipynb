# %% [markdown]
# # Quickstart Notebook\nUse the library from `src/options_lab`. Remember to install in editable mode or set `PYTHONPATH`.

# %%
from options_lab.black_scholes import bs_price, bs_greeks\nbs_price(100, 100, 0.05, 0.2, 1.0, 'call')
